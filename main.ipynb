# %%
#v1
import cv2
import numpy as np

# 1.we need to get background every 10 minutes.
# 2.we should make a threshold for the size of moving obj.
# 3.we should make a threshold for the displacement obj.
    
cap = cv2.VideoCapture(0)
fps = int(cap.get(cv2.CAP_PROP_FPS))
sec = 20
background_frames = []

for i in range(sec*fps):
    ret, frame = cap.read()
    background_frames.append(frame)
    if not ret:
        print("Failed to read frame")
        exit()

#get background  
background = np.average(background_frames, axis=0).astype(np.uint8)
# cv2.imshow('background',background)
gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
cv2.imshow('gray_background',gray_background)


while cap.isOpened():
    ret, frame = cap.read()
    # cv2.imshow("env", frame)
    
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # cv2.imshow('gray_frame',gray_frame)
    
    frame_diff = cv2.absdiff(gray_frame, gray_background)
    cv2.imshow("diff", frame_diff)
    
    # ret, thres = cv2.threshold(frame_diff, 50, 255, cv2.THRESH_BINARY)
    # cv2.imshow("binary_diff", thres)
    
    if cv2.waitKey(40) == 27 or ret != True:
        break

cv2.waitKey(0)
cv2.destroyAllWindows()
cap.release()

# %%
#v2
import cv2
import numpy as np

# 1.we need to get background every 10 minutes.
# 2.we should make a threshold for the size of moving obj.
# 3.we should make a threshold for the displacement obj.
    
cap = cv2.VideoCapture(0)
fps = int(cap.get(cv2.CAP_PROP_FPS))
sec = 5
background_frames = []

for i in range(sec*fps):
    ret, frame = cap.read()
    background_frames.append(frame)
    if not ret:
        print("Failed to read frame")
        exit()

#get background  
background = np.average(background_frames, axis=0).astype(np.uint8)
# cv2.imshow('background',background)
gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
# cv2.imshow('gray_background',gray_background)

# ret , thres = cv2.threshold(gray_background, 50, 255, cv2.THRESH_BINARY)
# cv2.imshow("b_diff", thres)
kernel=np.ones((10,10),np.uint8)
while cap.isOpened():
    ret, frame = cap.read()
    # cv2.imshow("env", frame)
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # cv2.imshow('gray_frame',gray_frame)
    
    frame_diff = cv2.absdiff(gray_frame, gray_background)
    # cv2.imshow("diff", frame_diff)
    
    thres = cv2.adaptiveThreshold(frame_diff,200,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11 ,2)
    cv2.imshow("binary_frame", thres)
    # cv2.imshow("binary_diff", thres)
    
    if cv2.waitKey(40) == 27 or ret != True:
        break

cv2.waitKey(0)
cv2.destroyAllWindows()
cap.release()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#v3
import cv2
import numpy as np

# 1.we need to get background every 10 minutes.
# 2.we should make a threshold for the size of moving obj.
# 3.we should make a threshold for the displacement obj.
    
cap = cv2.VideoCapture(0)
fps = int(cap.get(cv2.CAP_PROP_FPS))
sec = 20
background_frames = []

for i in range(sec*fps):
    ret, frame = cap.read()
    background_frames.append(frame)
    if not ret:
        print("Failed to read frame")
        exit()

#get background  
background = np.average(background_frames, axis=0).astype(np.uint8)
# cv2.imshow('background',background)
gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
cv2.imshow('gray_background',gray_background)


while cap.isOpened():
    ret, frame = cap.read()
    for i in range(sec*fps):
        background_frames.append(frame)
        if not ret:
            print("Failed to read frame")
            exit()

    #get background  
    background = np.average(background_frames, axis=0).astype(np.uint8)
    # cv2.imshow('background',background)
    gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
    cv2.imshow('gray_background',gray_background)

    # cv2.imshow("env", frame)
    
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # cv2.imshow('gray_frame',gray_frame)
    
    frame_diff = cv2.absdiff(gray_frame, gray_background)
    cv2.imshow("diff", frame_diff)
    
    ret, thres = cv2.threshold(frame_diff, 50, 255, cv2.THRESH_BINARY)
    cv2.imshow("binary_diff", thres)
    
    if cv2.waitKey(40) == 27 or ret != True:
        break

cv2.waitKey(0)
cv2.destroyAllWindows()
cap.release()

# %%
#v4
import cv2
import numpy as np

# 1. Capture background every 10 minutes.
# 2. Set a threshold for the size of moving obj.
# 3. Set a threshold for the displacement obj.

cap = cv2.VideoCapture(0)
fps = int(cap.get(cv2.CAP_PROP_FPS))
sec = 5


def get_background():
# Capture initial background frames
    background_frames = []  
    for i in range(sec * fps):
        ret, frame = cap.read()
        background_frames.append(frame)
        if not ret:
            print("Failed to read frame")
            exit()

    # Initialize background image and grayscale background
    background = np.average(background_frames, axis=0).astype(np.uint8)
    gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
    return gray_background

# Threshold value for detecting motion
threshold = 50


kernel = np.ones((5, 5))/25

frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()

    # Update background every 30 minutes (1800 frames)
    if frame_count % 1800 == 0:
        gray_background = get_background()
        
    # Calculate frame difference
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    frame_diff = cv2.absdiff(gray_frame, gray_background)
    cv2.imshow('frame_diff',frame_diff)

    # Apply threshold and dilation
    ret, thres = cv2.threshold(frame_diff, threshold, 255, cv2.THRESH_BINARY)
    # thres = cv2.dilate(thres, kernel, iterations=5)

    # Display binary image
    cv2.imshow("binary_frame", thres)
    # print("binary_frame")

    # Check for termination
    if cv2.waitKey(40) == 27 or not ret :
        break

    frame_count += 1

cv2.waitKey(0)
cv2.destroyAllWindows()
cap.release()

# %%
#v5
import cv2
import numpy as np

cap = cv2.VideoCapture(0)
fps = int(cap.get(cv2.CAP_PROP_FPS))
sec = 5
skip_frame = 0
kernel = np.ones((5, 5))/25
frame_count = 0


def get_background():
    background_frames = []  
    for i in range(sec * fps):
        ret, frame = cap.read()
        background_frames.append(frame)
        if not ret:
            print("Failed to read frame")
            exit()

    background = np.average(background_frames, axis=0).astype(np.uint8)
    gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
    return gray_background


while cap.isOpened():
    ret, frame = cap.read()

    if frame_count % 1800 == 0:
        gray_background = get_background()
        

    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    frame_diff = cv2.absdiff(gray_frame, gray_background)
    cv2.imshow('frame_diff',frame_diff)

    ret, thres = cv2.threshold(frame_diff, threshold, 255, cv2.THRESH_BINARY)
    thres = cv2.dilate(thres, kernel, iterations=1)

    # Display binary image
    cv2.imshow("binary_frame", thres)
    # print("binary_frame")

    contours, _ = cv2.findContours(thres, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for contour in contours:
        area = cv2.contourArea(contour)
        if area >1000:
        # Do something with the contour or its bounding box
            # x, y, w, h = cv2.boundingRect(contour)
            # cv2.rectangle(frame_diff, (x, y), (x + w, y + h), (0, 255, 0), 2)
            print(contour)
    # Check for termination
    if cv2.waitKey(40) == 27 or not ret :
        break

    frame_count += 1
    skip_frame += 1

cv2.waitKey(0)
cv2.destroyAllWindows()
cap.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\uni\motion detection\main.ipynb Cell 5 line 3
#      <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#W4sZmlsZQ%3D%3D?line=34'>35</a> frame_diff = cv2.absdiff(gray_frame, gray_background)
#      <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#W4sZmlsZQ%3D%3D?line=35'>36</a> cv2.imshow('frame_diff',frame_diff)
# ---> <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#W4sZmlsZQ%3D%3D?line=37'>38</a> ret, thres = cv2.threshold(frame_diff, threshold, 255, cv2.THRESH_BINARY)
#      <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#W4sZmlsZQ%3D%3D?line=38'>39</a> thres = cv2.dilate(thres, kernel, iterations=1)
#      <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#W4sZmlsZQ%3D%3D?line=40'>41</a> # Display binary image
#
# NameError: name 'threshold' is not defined
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2

# Read the image
image = cv2.imread('1.jpg')

# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding or other preprocessing steps if needed
# For example, you can use binary thresholding:
_, thresh = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY)

# Find contours in the thresholded image
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Iterate through contours and filter out those larger than 500 pixels
for contour in contours:
    area = cv2.contourArea(contour)
    if area > 500:
        # Do something with the contour or its bounding box
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Display the result
cv2.imshow('Result', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#v6
import cv2
import numpy as np


cap = cv2.VideoCapture(0)
fps = int(cap.get(cv2.CAP_PROP_FPS))
sec = 5
threshold = 50
kernel = np.ones((9, 9))/81
frame_count = 0

def get_background():
# Capture initial background frames
    background_frames = []  
    for i in range(sec * fps):
        ret, frame = cap.read()
        background_frames.append(frame)
        if not ret:
            print("Failed to read frame")
            exit()

    # Initialize background image and grayscale background
    background = np.average(background_frames, axis=0).astype(np.uint8)
    gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Gray_background',gray_background)
    return gray_background



while cap.isOpened():
    ret, frame = cap.read()

    # Update background every minute (1800 frames)
    if frame_count % 1800 == 0:
        gray_background = get_background()
        
    cv2.imshow('Real_video',frame)
    # Calculate frame difference
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    frame_diff = cv2.absdiff(gray_frame, gray_background)
    cv2.imshow('Frame_diff_of_background',frame_diff)

    # Apply threshold 
    thres = cv2.dilate(frame_diff, kernel, iterations=1)
    ret, thres = cv2.threshold(thres, threshold, 255, cv2.THRESH_BINARY)
    
    #finding contours
    contours, _ = cv2.findContours(thres, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for contour in contours:
    # Calculate area
        area = cv2.contourArea(contour)

    # Calculate perimeter
        perimeter = cv2.arcLength(contour, True)

    # Get bounding box
        x, y, w, h = cv2.boundingRect(contour)
    
    filtered_contours = []
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > 5000:  # Filter by minimum area
            filtered_contours.append(contour)

    for contour in filtered_contours:
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(thres, (x, y), (x + w, y + h), (255 ,255, 255), 4)

    # Display binary frame
    cv2.imshow("binary_frame", thres)

    # Check for termination
    if cv2.waitKey(40) == 27 or not ret :
        break

    frame_count += 1

cv2.waitKey(0)
cv2.destroyAllWindows()
cap.release()

# %%
#v7
import cv2
import numpy as np


cap = cv2.VideoCapture(0)
fps = int(cap.get(cv2.CAP_PROP_FPS))
sec = 5
threshold = 50
kernel = np.ones((9, 9))/81
frame_count = 0
x = np.ones

def get_background():
# Capture initial background frames
    background_frames = []  
    for i in range(sec * fps):
        ret, frame = cap.read()
        background_frames.append(frame)
        if not ret:
            print("Failed to read frame")
            exit()

    # Initialize background image and grayscale background
    background = np.average(background_frames, axis=0).astype(np.uint8)
    gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Gray_background',gray_background)
    return gray_background


new_background = get_background()

while cap.isOpened():
    ret, frame = cap.read()
    
    cv2.imshow('Real_video',frame)
    # Calculate frame difference
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # gray_frame=gray_frame.astype(np.float32)
    frame_diff = cv2.absdiff(gray_frame, new_background)
    cv2.imshow('Frame_diff_of_background',frame_diff)
    
    # Apply threshold 
    thres = cv2.dilate(frame_diff, kernel, iterations=1)
    ret, thres = cv2.threshold(thres, threshold, 255, cv2.THRESH_BINARY)
    
    #finding contours
    contours, _ = cv2.findContours(thres, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for contour in contours:
    # Calculate area
        area = cv2.contourArea(contour)

    # Calculate perimeter
        perimeter = cv2.arcLength(contour, True)

    # Get bounding box
        x, y, w, h = cv2.boundingRect(contour)
    
    filtered_contours = []
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > 5000:  # Filter by minimum area
            filtered_contours.append(contour)

    for contour in filtered_contours:
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(thres, (x, y), (x + w, y + h), (255 ,255, 255), 4)

    # Display binary frame
    cv2.imshow("binary_frame", thres)
    
    # Check for termination
    if cv2.waitKey(40) == 27 or not ret :
        break
    
    gray_background = new_background.astype(np.float32)
    old_background = np.multiply(gray_background, 0.99)
    # result_image1 = old_background.astype(np.uint8)
    
    new_frame = gray_frame.astype(np.float32)
    new_frame = np.multiply(new_frame, 0.01)
    # result_image2 = new_frame.astype(np.uint8)
    
    new_background = old_background + new_frame
    
    new_background = new_background.astype(np.uint8)
    cv2.imshow("new_bacground", new_background)
    

cv2.waitKey(0)
cv2.destroyAllWindows()
cap.release()

# %%
#v8
import cv2
import numpy as np
import math

cap = cv2.VideoCapture(0)
fps = int(cap.get(cv2.CAP_PROP_FPS))
sec = 5
threshold = 50
kernel = np.ones((9, 9))/81
frame_count = 0
# x = np.ones

def get_distance(center, x, y, w, h):
    # distance = abs(center[0]-(x+w/2))+(center[1]-(y+h/2))
    distance = math.sqrt((center[0] - (x + w/2))**2 + (center[1] - (y + h/2))**2)
    print(int(distance))
    # return distance 


def get_background():
# Capture initial background frames
    background_frames = []  
    for i in range(sec * fps):
        ret, frame = cap.read()
        background_frames.append(frame)
        if not ret:
            print("Failed to read frame")
            exit()

    # Initialize background image and grayscale background
    background = np.average(background_frames, axis=0).astype(np.uint8)
    gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
    # cv2.imshow('Gray_background',gray_background)
    gray_background = gray_background.astype(np.float32)
    height, width = gray_background.shape[:2]
    return gray_background, width , height


new_background , width , height= get_background()
center = (width/2 , height/2)

while cap.isOpened():
    ret, frame = cap.read()
    
    cv2.imshow('Real_video',frame)
    # Calculate frame difference
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray_frame=gray_frame.astype(np.float32)
    frame_diff =np.abs(gray_frame - new_background)
    
    
    frame_diff_uint8 = frame_diff.astype(np.uint8)
    cv2.imshow('Frame_diff_of_background',frame_diff)
    
    # Apply threshold 
    thres = cv2.dilate(frame_diff_uint8, kernel, iterations=1)
    ret, thres = cv2.threshold(thres, threshold, 255, cv2.THRESH_BINARY)
    
    #finding contours
    contours, _ = cv2.findContours(thres, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for contour in contours:
    # Calculate area
        area = cv2.contourArea(contour)

    # Calculate perimeter
        # perimeter = cv2.arcLength(contour, True)

    # Get bounding box
        x, y, w, h = cv2.boundingRect(contour)
    filtered_contours = []
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > (width*height)*0.02:  # Filter by minimum area
            filtered_contours.append(contour)
            get_distance(center, x, y, w, h)
            

    for contour in filtered_contours:
        x, y, w, h = cv2.boundingRect(contour)
        # get_distance()
        cv2.rectangle(thres, (x, y), (x + w, y + h), (255 ,255, 255), 4)

    # Display binary frame
    cv2.imshow("binary_frame", thres)
    
    # Check for termination
    if cv2.waitKey(40) == 27 or not ret :
        break
    
    old_background = np.multiply(new_background, 0.999)
    # result_image1 = old_background.astype(np.uint8)
    
    new_frame = np.multiply(gray_frame, 0.001)
    # result_image2 = new_frame.astype(np.uint8)
    
    new_background = old_background + new_frame
    
    new_b = new_background.astype(np.uint8)
    cv2.imshow("new_bacground", new_b)
    

cv2.waitKey(0)
cv2.destroyAllWindows()
cap.release()
# Out:
# 313
# 313
# 216
# 217
# 314
# 314
# 314
# 315
# 216
# 217
# 217
# 313
# 217
# 217
# 218
# 218
# 307
# 217
# 216
# 216
# 217
# 301
# 217
# 217
# 217
# 217
# 217
# 217
# 199
# 218
# 301
# 217
# 218
# 217
# 302
# 217
# 304
# 216
# 217
# 217
# 217
# 217
# 217
# 217
# 216
# 309
# 309
# 217
# 314
# 193
# 217
# 217
# 217
# 217
# 271
# 217
# 218
# 217
# 217
# 217
# 217
# 218
# 217
# 308
# 307
# 217
# 217
# 217
# 217
# 306
# 307
# 218
# 217
# 216
# 308
# 217
# 216
# 216
# 216
# 217
# 308
# 217
# 217
# 217
# 310
# 310
# 217
# 308
# 217
# 217
# 308
# 217
# 326
# 326
# 325
# 325
# 323
# 323
# 323
# 323
# 323
# 324
# 323
# 324
# 324
# 323
# 324
# 323
# 323
# 324
# 324
# 324
# 324
# 325
# 325
# 325
# 325
# 326
# 326
# 326
# 325
# 325
# 325
# 321
# 319
# 316
# 15
# 15
# 15
# 15
# 15
# 15
# 15
# 9
# 8
# 270
# 270
# 8
# 8
# 0
# 15
# 15
# 15
# 15
# 15
# 16
# 16
# 16
# 16
# 15
# 16
# 16
# 0
# 0
# 0
# 16
# 16
# 0
# 16
# 16
# 15
# 16
# 16
# 15
# 16
# 0
# 15
# 15
# 10
# 15
# 10
# 10
# 9
# 260
# 260
# 260
# 260
# 262
# 262
# 265
# 265
# 268
# 268
# 268
# 268
# 269
# 269
# 270
# 270
# 272
# 272
# 272
# 272
# 273
# 273
# 283
# 283
# 281
# 281
# 281
# 281
# 281
# 281
# 282
# 282
# 282
# 282
# 282
# 282
# 283
# 283
# 283
# 283
# 281
# 281
# 280
# 280
# 280
# 280
# 300
# 300
# 299
# 299
# 299
# 297
# 297
# 304
# 304
# 281
# 281
# 281
# 281
# 304
# 304
# 304
# 304
# 307
# 307
# 309
# 309
# 309
# 13
# 13
# 264
# 264
# 264
# 5
# 5
# 0
# 0
# 0
# 0
# 15
# 8
# 341
# 344
# 345
# 357
# 359
# 364
# 366
# 366
# 359
# 359
# 359
# 359
# 356
# 356
# 348
# 348
# 343
# 338
# 333
# 281
# 281
# 280
# 280
# 280
# 14
# 14
# 14
# 14
# 289
# 289
# 289
# 269
# 269
# 269
# 269
# 396
# 396
# 272
# 272
# 385
# 385
# 379
# 379
# 380
# 380
# 275
# 275
# 371
# 371
# 372
# 372
# 264
# 264
# 369
# 369
# 365
# 365
# 353
# 351
# 360
# 328
# 302
# 367
# 367
# 363
# 370
# 18
# 342
# 17
# 348
# 340
# 346
# 346
# 18
# 386
# 352
# 352
# 347
# 345
# 345
# 353
# 324
# 347

# %%
import cv2
import numpy as np
import skfuzzy  as fuzz
from skfuzzy import control as ctrl

# Load the image
image_path = 'path/to/your/image.jpg'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Fuzzy system design
brightness = ctrl.Antecedent(np.arange(0, 256, 1), 'brightness')
output_brightness = ctrl.Consequent(np.arange(0, 256, 1), 'output_brightness')

# Define fuzzy sets and membership functions
brightness['low'] = fuzz.trimf(brightness.universe, [0, 50, 100])
brightness['medium'] = fuzz.trimf(brightness.universe, [50, 100, 150])
brightness['high'] = fuzz.trimf(brightness.universe, [100, 150, 255])

output_brightness['low'] = fuzz.trimf(output_brightness.universe, [0, 50, 100])
output_brightness['medium'] = fuzz.trimf(output_brightness.universe, [50, 100, 150])
output_brightness['high'] = fuzz.trimf(output_brightness.universe, [100, 150, 255])

# Define rules
rule1 = ctrl.Rule(brightness['low'], output_brightness['low'])
rule2 = ctrl.Rule(brightness['medium'], output_brightness['medium'])
rule3 = ctrl.Rule(brightness['high'], output_brightness['high'])

# Create a control system
brightness_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])
brightness_adjustment = ctrl.ControlSystemSimulation(brightness_ctrl)

# Apply fuzzy logic to the image
adjusted_image = np.zeros_like(image)
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        brightness_adjustment.input['brightness'] = image[i, j]
        brightness_adjustment.compute()
        adjusted_image[i, j] = brightness_adjustment.output['output_brightness']

# Display the original and adjusted images
cv2.imshow('Original Image', image)
cv2.imshow('Adjusted Image', adjusted_image.astype(np.uint8))
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\uni\motion detection\main.ipynb Cell 10 line 4
#       <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> import skfuzzy  as fuzz
# ----> <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> from skfuzzy import control as ctrl
#       <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> # Load the image
#       <a href='vscode-notebook-cell:/d%3A/uni/motion%20detection/main.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a> image_path = 'path/to/your/image.jpg'
#
# File d:\uni\motion detection\venv\lib\site-packages\skfuzzy\control\__init__.py:15
#       1 """
#       2 skfuzzy.control subpackage, providing a high-level API for fuzzy system design.
#       3
#       4 """
#       6 __all__ = ['Antecedent',
#       7            'Consequent',
#       8            'ControlSystem',
#    (...)
#      12            'accumulation_mult',
#      13            ]
# ---> 15 from .antecedent_consequent import (Antecedent, Consequent,
#      16                                     accumulation_max, accumulation_mult)
#      17 from .controlsystem import ControlSystem, ControlSystemSimulation
#      18 from .rule import Rule
#
# File d:\uni\motion detection\venv\lib\site-packages\skfuzzy\control\antecedent_consequent.py:8
#       5 import networkx as nx
#       7 from .state import StatefulProperty
# ----> 8 from .fuzzyvariable import FuzzyVariable
#      11 def accumulation_max(*args):
#      12     """
#      13     Take the maximum of input values/arrays.
#      14
#      15     This is the default OR aggregation method for a fuzzy Rule.
#      16     """
#
# File d:\uni\motion detection\venv\lib\site-packages\skfuzzy\control\fuzzyvariable.py:7
#       4 import numpy as np
#       6 from ..membership import trimf
# ----> 7 from .visualization import FuzzyVariableVisualizer
#       8 from .term import Term
#      10 try:
#
# File d:\uni\motion detection\venv\lib\site-packages\skfuzzy\control\visualization.py:8
#       6 import numpy as np
#       7 import networkx as nx
# ----> 8 import matplotlib.pyplot as plt
#      10 from ..fuzzymath.fuzzy_ops import interp_membership
#      13 class FuzzyVariableVisualizer(object):
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import numpy as np
def get_distance(center, x, y, w, h):
    distance = abs(center[1]-(x+w/2), center[2]-(y+h/2))
    print(distance)
    # return distance

# %%
#v8
import cv2
import numpy as np
import math
import skfuzzy  as fuzz
from skfuzzy import control as ctrl

cap = cv2.VideoCapture(0)
fps = int(cap.get(cv2.CAP_PROP_FPS))
sec = 5
threshold = 20
kernel = np.ones((9, 9))/81
frame_count = 0

def get_distance(center, x, y, w, h):
    # distance = abs(center[0]-(x+w/2))+(center[1]-(y+h/2))
    distance = math.sqrt((center[0] - (x + w/2))**2 + (center[1] - (y + h/2))**2)
    # print(int(distance))
    return distance 

def get_difrence(x, y, w, h):
    # difrance = get_distance(center, x, y, w, h
    pass
    
    
def get_size(w, h):
    return w*h
    
def get_background():
    background_frames = []  
    for i in range(sec * fps):
        ret, frame = cap.read()
        background_frames.append(frame)
        if not ret:
            print("Failed to read frame")
            exit()

    # Initialize background image and grayscale background
    background = np.average(background_frames, axis=0).astype(np.uint8)
    gray_background = cv2.cvtColor(background, cv2.COLOR_BGR2GRAY)
    # cv2.imshow('Gray_background',gray_background)
    gray_background = gray_background.astype(np.float32)
    height, width = gray_background.shape[:2]
    return gray_background, width , height


new_background , width , height= get_background()
print(f"witdh:{width},h:{height} "  )
center = (width/2 , height/2)

# fuzzy inputs algorithm
max_distance = math.sqrt((width/2)**2 + (height/2)**2)
print(f"max_distance: {max_distance}")
distance = ctrl.Antecedent(np.arange(-1, max_distance, 1), 'distance')
difference = ctrl.Antecedent(np.arange(-1, 255, 1), 'difference')
size = ctrl.Antecedent(np.arange(-1, width*height, 1), 'size')
#fuzzy inputs algorithm
attention_level = ctrl.Consequent(np.arange(-1,100,1), "attention_level")

# Define fuzzy sets and membership functions
distance['low'] = fuzz.trapmf(distance.universe, [-1, 0, 120, 150])
distance['medium'] = fuzz.trapmf(distance.universe, [120, 150, 230, 266])
distance['high'] = fuzz.trapmf(distance.universe, [230, 266, 400, 401])

difference['low'] = fuzz.trapmf(difference.universe, [-1, 0, 75, 100])
difference['medium'] = fuzz.trapmf(difference.universe, [75, 100, 160, 180])
difference['high'] = fuzz.trapmf(difference.universe, [160, 180, 255, 256])

size['little'] = fuzz.trapmf(size.universe, [-1, 0, 92000, 112000])
size['medium'] = fuzz.trapmf(size.universe, [92000, 112000, 194000, 214000])
size['big'] = fuzz.trapmf(size.universe, [194000, 214000, 307199, 307200])

attention_level['low'] = fuzz.trapmf(attention_level.universe, [-1, 0, 30,40])
attention_level['medium'] = fuzz.trapmf(attention_level.universe, [30, 40, 60, 70])
attention_level['high'] = fuzz.trapmf(attention_level.universe, [60, 70, 100, 101])

# Rules:  
rule1 = ctrl.Rule(distance['low'] & difference['high'] & size['big'], attention_level['high'])
rule2 = ctrl.Rule(distance['low'] & difference['high'] & size['medium'], attention_level['high'])
rule3 = ctrl.Rule(distance['low'] & difference['high'] & size['little'], attention_level['high'])
rule4 = ctrl.Rule(distance['low'] & difference['medium'] & size['big'], attention_level['high'])
rule5 = ctrl.Rule(distance['low'] & difference['medium'] & size['medium'], attention_level['high'])
rule6 = ctrl.Rule(distance['low'] & difference['medium'] & size['little'], attention_level['medium'])
rule7 = ctrl.Rule(distance['low'] & difference['low'] & size['big'], attention_level['high'])
rule8 = ctrl.Rule(distance['low'] & difference['low'] & size['medium'], attention_level['medium'])
rule9 = ctrl.Rule(distance['low'] & difference['low'] & size['little'], attention_level['medium'])

rule10 = ctrl.Rule(distance['medium'] & difference['high'] & size['big'], attention_level['high'])
rule11 = ctrl.Rule(distance['medium'] & difference['high'] & size['medium'], attention_level['high'])
rule12 = ctrl.Rule(distance['medium'] & difference['high'] & size['little'], attention_level['medium'])
rule13 = ctrl.Rule(distance['medium'] & difference['medium'] & size['big'], attention_level['medium'])
rule14 = ctrl.Rule(distance['medium'] & difference['medium'] & size['medium'], attention_level['medium'])
rule15 = ctrl.Rule(distance['medium'] & difference['medium'] & size['little'], attention_level['low'])
rule16 = ctrl.Rule(distance['medium'] & difference['low'] & size['big'], attention_level['medium'])
rule17 = ctrl.Rule(distance['medium'] & difference['low'] & size['medium'], attention_level['medium'])
rule18 = ctrl.Rule(distance['medium'] & difference['low'] & size['little'], attention_level['low'])

rule19 = ctrl.Rule(distance['high'] & difference['high'] & size['big'], attention_level['medium'])
rule20 = ctrl.Rule(distance['high'] & difference['high'] & size['medium'], attention_level['medium'])
rule21 = ctrl.Rule(distance['high'] & difference['high'] & size['little'], attention_level['low'])
rule22 = ctrl.Rule(distance['high'] & difference['medium'] & size['big'], attention_level['medium'])
rule23 = ctrl.Rule(distance['high'] & difference['medium'] & size['medium'], attention_level['low'])
rule24 = ctrl.Rule(distance['high'] & difference['medium'] & size['little'], attention_level['low'])
rule25 = ctrl.Rule(distance['high'] & difference['low'] & size['big'], attention_level['low'])
rule26 = ctrl.Rule(distance['high'] & difference['low'] & size['medium'], attention_level['low'])
rule27 = ctrl.Rule(distance['high'] & difference['low'] & size['little'] , attention_level['low'])

# Create control system
motion_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7, rule8, rule9
                                  , rule10, rule11, rule12, rule13, rule14, rule15, rule16, rule17
                                  , rule18, rule19, rule20, rule21, rule22, rule23, rule24, rule25,
                                  rule26, rule27])
motion_detection = ctrl.ControlSystemSimulation(motion_ctrl)

while cap.isOpened():
    ret, frame = cap.read()
    
    cv2.imshow('Real_video',frame)
    # Calculate frame difference
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray_frame=gray_frame.astype(np.float32)
    frame_diff =np.abs(gray_frame - new_background)
    
    
    frame_diff_uint8 = frame_diff.astype(np.uint8)
    cv2.imshow('Frame_diff_of_background',frame_diff_uint8)
    
    # Apply threshold 
    thres = cv2.dilate(frame_diff_uint8, kernel, iterations=1)
    ret, thres = cv2.threshold(thres, threshold, 255, cv2.THRESH_BINARY)
    
    #finding contours
    contours, _ = cv2.findContours(thres, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    for contour in contours:
    # Calculate area
        area = cv2.contourArea(contour)

    # Calculate perimeter
        # perimeter = cv2.arcLength(contour, True)

    # Get bounding box
        x, y, w, h = cv2.boundingRect(contour)
    filtered_contours = []
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > (width*height)*0.02:  # Filter by minimum area
            filtered_contours.append(contour)
            distance = get_distance(center, x, y, w, h)
            size_fuzzy=get_size(w,h)
            # motion_detection.input['distance'] = distance
            
            contor_center = x + w/2, y + h/2
            
    for contour in filtered_contours:
        x, y, w, h = cv2.boundingRect(contour)
        cv2.rectangle(thres, (x, y), (x + w, y + h), (255 ,255, 255), 4)

    # Display binary frame
    cv2.imshow("binary_frame", thres)
    
    motion_detection.input['distance'] = distance  # Replace with your actual distance value
    motion_detection.input['difference'] = difference  # Replace with your actual difference value
    motion_detection.input['size'] = size
    # Check for termination
    if cv2.waitKey(40) == 27 or not ret :
        break
    
    old_background = np.multiply(new_background, 0.999)
    # result_image1 = old_background.astype(np.uint8)
    
    new_frame = np.multiply(gray_frame, 0.001)
    # result_image2 = new_frame.astype(np.uint8)
    
    new_background = old_background + new_frame
    
    new_b = new_background.astype(np.uint8)
    cv2.imshow("new_bacground", new_b)
    

cv2.waitKey(0)
cv2.destroyAllWindows()
cap.release()
# Out:
# witdh:640,h:480
# max_distance: 400.0
